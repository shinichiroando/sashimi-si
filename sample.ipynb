# %%
from sashimi_si import *
import matplotlib.pyplot as plt

plt.rc('font', **{'family':'sans-serif','size':15})
plt.rc('text', usetex=False)
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)
plt.rcParams['xtick.major.size']  = 5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.size']  = 2
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.size']  = 5
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.size']  = 2
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.direction']   = 'in'
plt.rcParams['ytick.direction']   = 'in'
plt.rcParams['xtick.major.pad']   = 8
plt.rcParams['xtick.top']         = True
plt.rcParams['ytick.right']       = True

# %% [markdown]
# # Specify SIDM parameters
#
# First, read the 'subhalo_properties' class with SIDM parameters $\sigma_0/m_\chi$ and $w$. Here, we show a specific example with $\sigma_0/m_\chi = 147.1~\mathrm{cm^{2}~g^{-1}}$ and $w = 24.33~\mathrm{km~s^{-1}}$.

# %%
sh = subhalo_properties(sigma0_m=147.1,w=24.33)

# %% [markdown]
# # Calculate subhalo properties
#
# Then you obtain various subhalo quantities by specifying the host parameters such as the mass and redshift. These are subhalo masses and density profile parameters $r_s$, $\rho_s$, and $\rho_c$ for SIDM and corresponding CDM. Read the documentation of the subhalo_properties function for full details. Note that subhalos are assumed to follow the NFW profile for CDM and cored-NFW profile for SIDM. See the paper for details.

# %%
ma200, z_acc, rsCDM_acc, rhosCDM_acc, rmaxCDM_acc, VmaxCDM_acc, rsSIDM_acc, rhosSIDM_acc, rcSIDM_acc, rmaxSIDM_acc, VmaxSIDM_acc, m_z0, rsCDM_z0, rhosCDM_z0, rmaxCDM_z0, VmaxCDM_z0, rsSIDM_z0, rhosSIDM_z0, rcSIDM_z0, rmaxSIDM_z0, VmaxSIDM_z0, ctCDM_z0, tt_ratio, weightCDM, weightSIDM, surviveCDM, surviveSIDM = sh.subhalo_properties_calc(1.e12*sh.Msun,redshift=0.,M0_at_redshift=True,dz=0.01,N_herm=20,zmax=5.,logmamin=6,N_ma=500)
# Out:
# Calculating subhalo properties:   0%|          | 0/179 [00:00<?, ?it/s]
# Calculating subhalo properties:   1%|          | 1/179 [00:00<00:41,  4.27it/s]
# Calculating subhalo properties:   1%|          | 2/179 [00:00<00:39,  4.49it/s]
# Calculating subhalo properties:   2%|▏         | 3/179 [00:00<00:38,  4.59it/s]
# Calculating subhalo properties:   2%|▏         | 4/179 [00:00<00:37,  4.63it/s]
# Calculating subhalo properties:   3%|▎         | 5/179 [00:01<00:37,  4.64it/s]
# Calculating subhalo properties:   3%|▎         | 6/179 [00:01<00:36,  4.69it/s]
# Calculating subhalo properties:   4%|▍         | 7/179 [00:01<00:36,  4.65it/s]
# Calculating subhalo properties:   4%|▍         | 8/179 [00:01<00:37,  4.57it/s]
# Calculating subhalo properties:   5%|▌         | 9/179 [00:01<00:37,  4.58it/s]
# Calculating subhalo properties:   6%|▌         | 10/179 [00:02<00:36,  4.58it/s]
# Calculating subhalo properties:   6%|▌         | 11/179 [00:02<00:36,  4.58it/s]
# Calculating subhalo properties:   7%|▋         | 12/179 [00:02<00:36,  4.58it/s]
# Calculating subhalo properties:   7%|▋         | 13/179 [00:02<00:36,  4.56it/s]
# Calculating subhalo properties:   8%|▊         | 14/179 [00:03<00:36,  4.57it/s]
# Calculating subhalo properties:   8%|▊         | 15/179 [00:03<00:35,  4.58it/s]
# Calculating subhalo properties:   9%|▉         | 16/179 [00:03<00:35,  4.61it/s]
# Calculating subhalo properties:   9%|▉         | 17/179 [00:03<00:35,  4.61it/s]
# Calculating subhalo properties:  10%|█         | 18/179 [00:03<00:35,  4.55it/s]
# Calculating subhalo properties:  11%|█         | 19/179 [00:04<00:35,  4.56it/s]
# Calculating subhalo properties:  11%|█         | 20/179 [00:04<00:34,  4.59it/s]
# Calculating subhalo properties:  12%|█▏        | 21/179 [00:04<00:34,  4.62it/s]
# Calculating subhalo properties:  12%|█▏        | 22/179 [00:04<00:34,  4.58it/s]
# Calculating subhalo properties:  13%|█▎        | 23/179 [00:05<00:33,  4.60it/s]
# Calculating subhalo properties:  13%|█▎        | 24/179 [00:05<00:33,  4.60it/s]
# Calculating subhalo properties:  14%|█▍        | 25/179 [00:05<00:33,  4.60it/s]
# Calculating subhalo properties:  15%|█▍        | 26/179 [00:05<00:33,  4.61it/s]
# Calculating subhalo properties:  15%|█▌        | 27/179 [00:05<00:33,  4.59it/s]
# Calculating subhalo properties:  16%|█▌        | 28/179 [00:06<00:32,  4.59it/s]
# Calculating subhalo properties:  16%|█▌        | 29/179 [00:06<00:32,  4.61it/s]
# Calculating subhalo properties:  17%|█▋        | 30/179 [00:06<00:32,  4.58it/s]
# Calculating subhalo properties:  17%|█▋        | 31/179 [00:06<00:32,  4.58it/s]
# Calculating subhalo properties:  18%|█▊        | 32/179 [00:06<00:32,  4.59it/s]
# Calculating subhalo properties:  18%|█▊        | 33/179 [00:07<00:31,  4.62it/s]
# Calculating subhalo properties:  19%|█▉        | 34/179 [00:07<00:31,  4.61it/s]
# Calculating subhalo properties:  20%|█▉        | 35/179 [00:07<00:31,  4.59it/s]
# Calculating subhalo properties:  20%|██        | 36/179 [00:07<00:31,  4.55it/s]
# Calculating subhalo properties:  21%|██        | 37/179 [00:08<00:30,  4.59it/s]
# Calculating subhalo properties:  21%|██        | 38/179 [00:08<00:30,  4.64it/s]
# Calculating subhalo properties:  22%|██▏       | 39/179 [00:08<00:30,  4.64it/s]
# Calculating subhalo properties:  22%|██▏       | 40/179 [00:08<00:30,  4.63it/s]
# Calculating subhalo properties:  23%|██▎       | 41/179 [00:08<00:29,  4.62it/s]
# Calculating subhalo properties:  23%|██▎       | 42/179 [00:09<00:29,  4.62it/s]
# Calculating subhalo properties:  79%|███████▉  | 142/179 [00:31<00:08,  4.56it/s]
# Calculating subhalo properties:  80%|███████▉  | 143/179 [00:31<00:07,  4.56it/s]
# Calculating subhalo properties:  80%|████████  | 144/179 [00:31<00:07,  4.58it/s]
# Calculating subhalo properties:  81%|████████  | 145/179 [00:31<00:07,  4.55it/s]
# Calculating subhalo properties:  82%|████████▏ | 146/179 [00:31<00:07,  4.56it/s]
# Calculating subhalo properties:  82%|████████▏ | 147/179 [00:32<00:07,  4.49it/s]
# Calculating subhalo properties:  83%|████████▎ | 148/179 [00:32<00:06,  4.48it/s]
# Calculating subhalo properties:  83%|████████▎ | 149/179 [00:32<00:07,  4.28it/s]
# Calculating subhalo properties:  84%|████████▍ | 150/179 [00:32<00:06,  4.38it/s]
# Calculating subhalo properties:  84%|████████▍ | 151/179 [00:33<00:06,  4.43it/s]
# Calculating subhalo properties:  85%|████████▍ | 152/179 [00:33<00:06,  4.49it/s]
# Calculating subhalo properties:  85%|████████▌ | 153/179 [00:33<00:05,  4.49it/s]
# Calculating subhalo properties:  86%|████████▌ | 154/179 [00:33<00:05,  4.49it/s]
# Calculating subhalo properties:  87%|████████▋ | 155/179 [00:33<00:05,  4.50it/s]
# Calculating subhalo properties:  87%|████████▋ | 156/179 [00:34<00:05,  4.44it/s]
# Calculating subhalo properties:  88%|████████▊ | 157/179 [00:34<00:04,  4.45it/s]
# Calculating subhalo properties:  88%|████████▊ | 158/179 [00:34<00:04,  4.46it/s]
# Calculating subhalo properties:  89%|████████▉ | 159/179 [00:34<00:04,  4.41it/s]
# Calculating subhalo properties:  89%|████████▉ | 160/179 [00:35<00:04,  4.42it/s]
# Calculating subhalo properties:  90%|████████▉ | 161/179 [00:35<00:04,  4.40it/s]
# Calculating subhalo properties:  91%|█████████ | 162/179 [00:35<00:03,  4.41it/s]
# Calculating subhalo properties:  91%|█████████ | 163/179 [00:35<00:03,  4.42it/s]
# Calculating subhalo properties:  92%|█████████▏| 164/179 [00:35<00:03,  4.46it/s]
# Calculating subhalo properties:  92%|█████████▏| 165/179 [00:36<00:03,  4.40it/s]
# Calculating subhalo properties:  93%|█████████▎| 166/179 [00:36<00:02,  4.46it/s]
# Calculating subhalo properties:  93%|█████████▎| 167/179 [00:36<00:02,  4.44it/s]
# Calculating subhalo properties:  94%|█████████▍| 168/179 [00:36<00:02,  4.44it/s]
# Calculating subhalo properties:  94%|█████████▍| 169/179 [00:37<00:02,  4.45it/s]
# Calculating subhalo properties:  95%|█████████▍| 170/179 [00:37<00:02,  4.43it/s]
# Calculating subhalo properties:  96%|█████████▌| 171/179 [00:37<00:01,  4.46it/s]
# Calculating subhalo properties:  96%|█████████▌| 172/179 [00:37<00:01,  4.44it/s]
# Calculating subhalo properties:  97%|█████████▋| 173/179 [00:37<00:01,  4.46it/s]
# Calculating subhalo properties:  97%|█████████▋| 174/179 [00:38<00:01,  4.39it/s]
# Calculating subhalo properties:  98%|█████████▊| 175/179 [00:38<00:00,  4.43it/s]
# Calculating subhalo properties:  98%|█████████▊| 176/179 [00:38<00:00,  4.43it/s]
# Calculating subhalo properties:  99%|█████████▉| 177/179 [00:38<00:00,  4.44it/s]
# Calculating subhalo properties:  99%|█████████▉| 178/179 [00:39<00:00,  4.39it/s]
# Calculating subhalo properties: 100%|██████████| 179/179 [00:39<00:00,  4.34it/s]
# Calculating subhalo properties: 100%|██████████| 179/179 [00:39<00:00,  4.55it/s]

# %% [markdown]
# # Distribution of $V_{\rm max}$ and $r_{\rm max}$
#
# Next, we show how we make the 'heat map' for distribution of two of the density profile paramters $V_{\rm max}$ and $r_{\rm max}$. We show them for both the CDM and SIDM in the following. As a threshold mass, we adopt $m_{\rm sh} = 10^8 M_{\odot}/h$.

# %% [markdown]
# ## CDM

# %%
mth = 1.e8*sh.Msun/sh.h
condition = (m_z0>mth)*(weightSIDM>0.)

q1 = VmaxCDM_z0[condition]/(sh.km/sh.s)
q2 = rmaxCDM_z0[condition]/sh.kpc

N,x_edges,y_edges = np.histogram2d(np.log(np.maximum(q1,0.001)),np.log(q2),weights=weightCDM[condition],bins=[30,30])
x = (x_edges[:-1]+x_edges[1:])/2.
y = (y_edges[:-1]+y_edges[1:])/2.
dx = (x_edges[1:]-x_edges[:-1])[0]
dy = (y_edges[1:]-y_edges[:-1])[0]
d2Ndxdy = N/dx/dy
plt.xscale('log')
plt.yscale('log')
plt.xlim(5e0,1e2)
plt.ylim(1e-1,5e1)
plt.xlabel(r'$V_{\rm max} \ [\mathrm{km/s}]$')
plt.ylabel(r'$r_{\rm max} \ [\mathrm{kpc}]$')
plt.title(r'CDM ($m_{\rm sh}>10^{8}M_{\odot}/h$)')
levels = np.linspace(-3,2,21)
plt.contourf(np.exp(x),np.exp(y),np.log10(d2Ndxdy.T),levels=levels,cmap='RdBu_r')
cbar = plt.colorbar(ticks=np.arange(2,-3.1,-1))
cbar.set_label(r'$\log(d^{2}N_{\rm sh}/d\ln\,V_{\rm max}/d\ln\,r_{\rm max})$',fontsize=15)

plt.show()

# %% [markdown]
# ## SIDM

# %%
mth = 1.e8*sh.Msun/sh.h
condition = (m_z0>mth)*(weightSIDM>0.)

q1 = VmaxSIDM_z0[condition]/(sh.km/sh.s)
q2 = rmaxSIDM_z0[condition]/sh.kpc

N,x_edges,y_edges = np.histogram2d(np.log(np.maximum(q1,0.001)),np.log(q2),weights=weightSIDM[condition],bins=[30,30])
x = (x_edges[:-1]+x_edges[1:])/2.
y = (y_edges[:-1]+y_edges[1:])/2.
dx = (x_edges[1:]-x_edges[:-1])[0]
dy = (y_edges[1:]-y_edges[:-1])[0]
d2Ndxdy = N/dx/dy
plt.xscale('log')
plt.yscale('log')
plt.xlim(5e0,1e2)
plt.ylim(1e-1,5e1)
plt.xlabel(r'$V_{\rm max} \ [\mathrm{km/s}]$')
plt.ylabel(r'$r_{\rm max} \ [\mathrm{kpc}]$')
plt.title(r'SIDM ($m_{\rm sh}>10^{8}M_{\odot}/h$)')
levels = np.linspace(-3,2,21)
plt.contourf(np.exp(x),np.exp(y),np.log10(d2Ndxdy.T),levels=levels,cmap='RdBu_r')
cbar = plt.colorbar(ticks=np.arange(2,-3.1,-1))
cbar.set_label(r'$\log(d^{2}N_{\rm sh}/d\ln\,V_{\rm max}/d\ln\,r_{\rm max})$',fontsize=15)

plt.show()

# %% [markdown]
# # Generating a subhalo sample.
#
# We randomly generate subhalos following these distributions via Monte Carlo.

# %%
mth = 1.e8*sh.Msun/sh.h
condition = (m_z0>mth)*(weightSIDM>0.)

q1 = VmaxSIDM_z0[condition]/(sh.km/sh.s)
q2 = rmaxSIDM_z0[condition]/sh.kpc
c = tt_ratio[condition]
w = weightSIDM[condition]
p = w/np.sum(w)

mu_tot = np.sum(w)
N_tot = np.random.poisson(mu_tot)

index_random = np.random.choice(np.arange(len(p)),size=N_tot,p=p)
logVmax = q1[index_random]
logrmax = q2[index_random]
c = c[index_random]
c = np.minimum(c,1.)

plt.xscale('log')
plt.yscale('log')
plt.xlim(5e0,1e2)
plt.ylim(1e-1,5e1)
plt.xlabel(r'$V_{\rm max} \ [\mathrm{km/s}]$')
plt.ylabel(r'$r_{\rm max} \ [\mathrm{kpc}]$')
plt.title(r'SIDM ($m_{\rm sh}>10^{8}M_{\odot}/h$)')
plt.scatter(logVmax,logrmax,c=c,s=3,cmap='RdBu_r')
cbar = plt.colorbar(ticks=np.arange(1,-0.1,-0.2))
cbar.set_label(r'$t_L(z_f)/t_c$',fontsize=15)
plt.show()

# %% [markdown]
# # Subhalo mass function
#
# We then plot the subhalo mass function $dN_{\rm sh}/dm$ for all the SIDM subhalos and collapsed ones.

# %%
condition = weightSIDM>0.
q = m_z0[condition]/sh.Msun
N,lnx_edges = np.histogram(np.log(q),weights=weightSIDM[condition],bins=100)
lnx = (lnx_edges[1:]+lnx_edges[:-1])/2.
x = np.exp(lnx)
dlnx = lnx_edges[1:]-lnx_edges[:-1]
dNdlnx = N/dlnx
plt.loglog(x,dNdlnx,':',c='k',label='SIDM (all)')

condition = (weightSIDM>0.)*(tt_ratio>1.)
q = m_z0[condition]/sh.Msun
N,lnx_edges = np.histogram(np.log(q),weights=weightCDM[condition],bins=100)
lnx = (lnx_edges[1:]+lnx_edges[:-1])/2.
x = np.exp(lnx)
dlnx = lnx_edges[1:]-lnx_edges[:-1]
dNdlnx = N/dlnx
plt.loglog(x,dNdlnx,'-',label=r'SIDM ($t_L(z_f)/t_c>1$)')

plt.ylim(1e-2,1e5)
plt.xlim(1e6,1e11)
plt.legend(fontsize=13)
plt.xlabel(r'$m_{\rm sh} \ [M_{\odot}]$')
plt.ylabel(r'$dN_{\rm sh}/d\ln m_{\rm sh}$')
plt.show()
